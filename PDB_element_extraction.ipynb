# %%
import pandas as pd

# %%
df = pd.read_csv('all_formula.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-c923bc509b2c> in <module>
# ----> 1 df = pd.read_csv('all_formula.csv', index=False)
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
df
# Out:
#                      formula
# 0                   C6 H6 O4
# 1              C11 H8 Cl2 O3
# 2             C11 H11 F N2 O
# 3            C26 H25 F2 N O9
# 4              C25 H20 N4 O6
# 5           C16 H9 Cl F N O2
# 6               C12 H10 F N5
# 7              C3 H3 Cl N2 S
# 8            C16 H33 N2 O7 P
# 9              C21 H27 N7 O3
# 10             C28 H32 N4 O5
# 11              C7 H14 N2 O2
# 12              C13 H22 N4 O
# 13              C11 H11 N O3
# 14             C31 H27 N3 O4
# 15          C42 H56 N10 O6 S
# 16         C12 H20 Cl4 N2 O2
# 17     C21 H23 Fe N6 O13 P S
# 18           C29 H25 F N4 O5
# 19          C17 H13 Br N4 O2
# 20            C24 H34 N8 O S
# 21              C18 H23 N O2
# 22            C38 H57 N7 O10
# 23          C18 H14 Cl2 O3 S
# 24             C15 H30 N5 O5
# 25             C14 H20 N2 O4
# 26                C14 H16 O4
# 27                 C11 H14 O
# 28        C22 H27 Cl N6 O4 S
# 29                C5 H4 N4 O
# ...                      ...
# ...

# %%
symbols = (
    'H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg', 'Al',
    'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe',
    'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr',
    'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn',
    'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm',
    'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W',
    'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn',
    'Fr', 'Ra', 'Ac', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf',
    'Es', 'Fm', 'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt', 'Ds',
    'Rg', 'Cn', 'Uut', 'Fl', 'Uup', 'Lv', 'Uus', 'Uuo'
)

# %%
def extract_element(formula):
    s = str(formula)
    result = ''.join([i for i in s if not i.isdigit()])
    element_string = result.replace(" ", ",")
    return element_string

# %%
m = extract_element('C24 H24 Cl F N2 O')

# %%
print(m)
# Out:
# C,H,Cl,F,N,O

# %%
df['formula']
# Out:
# 0                     C6 H6 O4
# 1                C11 H8 Cl2 O3
# 2               C11 H11 F N2 O
# 3              C26 H25 F2 N O9
# 4                C25 H20 N4 O6
# 5             C16 H9 Cl F N O2
# 6                 C12 H10 F N5
# 7                C3 H3 Cl N2 S
# 8              C16 H33 N2 O7 P
# 9                C21 H27 N7 O3
# 10               C28 H32 N4 O5
# 11                C7 H14 N2 O2
# 12                C13 H22 N4 O
# 13                C11 H11 N O3
# 14               C31 H27 N3 O4
# 15            C42 H56 N10 O6 S
# 16           C12 H20 Cl4 N2 O2
# 17       C21 H23 Fe N6 O13 P S
# 18             C29 H25 F N4 O5
# 19            C17 H13 Br N4 O2
# 20              C24 H34 N8 O S
# 21                C18 H23 N O2
# 22              C38 H57 N7 O10
# 23            C18 H14 Cl2 O3 S
# 24               C15 H30 N5 O5
# 25               C14 H20 N2 O4
# 26                  C14 H16 O4
# 27                   C11 H14 O
# 28          C22 H27 Cl N6 O4 S
# 29                  C5 H4 N4 O
# ...

# %%
df_new = df['formula'].apply(extract_element)

# %%
list_of_element = (','.join(df_new))

# %%
list_of_element
# Out:
# 'C,H,O,C,H,Cl,O,C,H,F,N,O,C,H,F,N,O,C,H,N,O,C,H,Cl,F,N,O,C,H,F,N,C,H,Cl,N,S,C,H,N,O,P,C,H,N,O,C,H,N,O,C,H,N,O,C,H,N,O,C,H,N,O,C,H,N,O,C,H,N,O,S,C,H,Cl,N,O,C,H,Fe,N,O,P,S,C,H,F,N,O,C,H,Br,N,O,C,H,N,O,S,C,H,N,O,C,H,N,O,C,H,Cl,O,S,C,H,N,O,C,H,N,O,C,H,O,C,H,O,C,H,Cl,N,O,S,C,H,N,O,C,H,O,C,H,F,N,O,C,H,Br,N,O,P,C,H,F,N,O,S,C,H,O,C,H,N,C,H,N,O,P,C,H,N,O,Cl,Re,C,H,N,O,S,C,H,N,O,C,H,O,C,H,N,O,P,C,H,N,O,C,H,N,O,C,H,O,P,O,S,C,H,N,O,P,C,H,O,P,S,C,H,N,O,S,C,H,N,S,C,H,F,N,O,S,C,H,F,N,O,Ru,C,H,N,O,C,H,N,O,C,H,N,S,C,H,N,O,C,H,N,O,C,H,N,O,C,H,Cl,F,N,C,H,O,C,H,N,O,C,H,Cl,N,O,C,H,Cl,N,C,H,F,N,O,S,C,H,N,O,P,C,H,F,N,O,P,C,H,N,O,C,H,N,O,C,H,N,O,C,H,N,O,S,C,H,O,C,H,Cl,N,O,S,C,H,F,N,O,P,C,H,O,P,C,H,N,S,C,H,N,O,C,H,N,O,C,H,N,O,C,H,N,O,C,H,N,O,C,H,F,N,O,C,H,N,O,C,H,F,N,O,S,C,H,N,O,C,H,Cl,N,O,S,C,H,N,O,C,H,N,O,C,H,Cl,N,O,C,H,F,N,S,C,H,N,O,P,C,H,O,C,H,Cl,N,O,C,H,F,N,O,P,C,H,N,O,S,C,H,I,O,S,C,H,N,O,C,H,N,O,S,C,H,O,S,C,H,O,C,H,F,N,O,S,C,H,N,O,C,H,N,O,C,H,N,O,S,C,H,Cl,N,O,S,C,H,N,O,C,H,F,N,O,C,H,F,N,O,C,H,N,C,H,O,C
# ...

# %%
list_of_unique_element = list_of_element.split(",")

# %%
list_of_unique_element
# Out:
# ['C',
#  'H',
#  'O',
#  'C',
#  'H',
#  'Cl',
#  'O',
#  'C',
#  'H',
#  'F',
#  'N',
#  'O',
#  'C',
#  'H',
#  'F',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'Cl',
#  'F',
#  'N',
#  'O',
#  'C',
#  'H',
#  'F',
#  'N',
#  'C',
#  'H',
#  'Cl',
#  'N',
#  'S',
#  'C',
#  'H',
#  'N',
#  'O',
#  'P',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'S',
#  'C',
#  'H',
#  'Cl',
#  'N',
#  'O',
#  'C',
#  'H',
#  'Fe',
#  'N',
#  'O',
#  'P',
#  'S',
#  'C',
#  'H',
#  'F',
#  'N',
#  'O',
#  'C',
#  'H',
#  'Br',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'S',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'Cl',
#  'O',
#  'S',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'N',
#  'O',
#  'C',
#  'H',
#  'O',
#  'C',
#  'H',
#  'O',
# ...

# %%
#unique_elemnt = ''.join(set(list_of_unique_element))

# %%
unique_element = []

# %%
for x in list_of_unique_element:
    if x not in list_of_unique_element:
        unique_element.append(x)

# %%
print(set(list_of_unique_element))
# Out:
# {'Sc', 'NI', 'Tl', 'FE', 'Ga', 'Pu', 'Er', 'Sb', 'Cm', 'Pr', 'Cu', 'Sm', 'F', 'Ru', 'Ag', 'nan', 'V', 'B', 'Bi', 'Ta', 'Pt', 'Ar', 'Ca', 'P', 'CL', 'Os', 'Ni', 'As', 'Rb', 'W', 'Co', 'BR', 'Th', 'Ba', 'La', 'Eu', 'Zn', 'Br', 'Li', 'U', 'Ti', 'Cr', 'Yb', 'Hg', 'In', 'Mo', 'Ce', 'N', 'H', 'Tb', 'S', 'Re', 'Cl', 'Mg', 'Mn', 'D', 'Rh', 'Sn', 'Te', 'I', 'K', 'Zr', 'Pd', 'Au', 'Xe', 'C', 'O', 'Y', 'Cs', 'Na', 'Fe', 'Sr', 'Se', 'Lu', 'Ho', 'Si', 'Cf', 'Al', 'Dy', 'Hf', 'X', 'Kr', 'Ir', 'Pb', 'Gd', 'Am', 'Cd', 'Be'}
